# %%
import requests
import pandas as pd

# %% [markdown]
# # Retrieve Data from the API

# %% [markdown]
# The goal is to retrieve the counting data for bike channels in Lyon Metropole from the API and store it in a CSV file.

# %% [markdown]
# For that, we will use the requests library to make HTTP requests to the API and pandas to handle the data.

# %%
channels_data = pd.read_csv('./CSVs/channels.csv', sep=';')
test = False
channels_ID = []
if not test:
    channels_ID = channels_data['channel_id'].tolist()
else:
    channels_ID = [102017788, 353246254, 353246258]

START_DATE = '2022-04-01'
END_DATE = '2022-04-30'

# %%
def request_counting_data(channel_id, start_date, end_date):
    url = f'https://data.grandlyon.com/fr/datapusher/ws/timeseries/pvo_patrimoine_voirie.pvocomptagemeasure/all.json?start_datetime__gte={start_date}&start_datetime__lt={end_date}&channel_id__eq={channel_id}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        values = data['values']
        df = pd.DataFrame(values)
        return df
    else:
        print(f"Failed to retrieve data for channel {channel_id}")
        return pd.DataFrame()

# %%
def retrieve_data_for_channels(channel_ids, start_date, end_date):
    all_data = pd.DataFrame()
    for channel_id in channel_ids:
        print(f"Retrieving data for channel {channel_id}")
        channel_data = request_counting_data(channel_id, start_date, end_date)
        all_data = pd.concat([all_data, channel_data], ignore_index=True)
    return all_data

# %%
all_data = retrieve_data_for_channels(channels_ID, START_DATE, END_DATE)
all_data
# Out:
# Retrieving data for channel 102017788
# Retrieving data for channel 353246254
# Retrieving data for channel 353246258
# Retrieving data for channel 103030637
# Retrieving data for channel 101017789
# Retrieving data for channel 102017789
# Retrieving data for channel 353243336
# Retrieving data for channel 353243340
# Retrieving data for channel 101017791
# Retrieving data for channel 102017791
# Retrieving data for channel 353243817
# Retrieving data for channel 353244043
# Retrieving data for channel 353244047
# Retrieving data for channel 101017792
# Retrieving data for channel 102017792
# Retrieving data for channel 353244355
# Retrieving data for channel 353299938
# Retrieving data for channel 353299942
# Retrieving data for channel 101024515
# Retrieving data for channel 353244359
# Retrieving data for channel 101017788
# Retrieving data for channel 101017793
# Retrieving data for channel 102017793
# Retrieving data for channel 353243839
# Retrieving data for channel 353243804
# Retrieving data for channel 353243826
# Retrieving data for channel 353479672
# Retrieving data for channel 353478481
# Retrieving data for channel 101030106
# Retrieving data for channel 102030106
# Retrieving data for channel 101030107
# Retrieving data for channel 102030107
# Retrieving data for channel 353478482
# Retrieving data for channel 353399232
# Retrieving data for channel 102024515
# Retrieving data for channel 353243192
# Retrieving data for channel 353243196
# Retrieving data for channel 353479670
# Retrieving data for channel 102026724
# Retrieving data for channel 101026724
# Retrieving data for channel 103026959
# Retrieving data for channel 104026959
# Retrieving data for channel 101032799
# Retrieving data for channel 102032799
# Retrieving data for channel 101032800
# Retrieving data for channel 101032795
# Retrieving data for channel 102032795
# Retrieving data for channel 102032800
# Retrieving data for channel 101032820
# Retrieving data for channel 102032820
# Retrieving data for channel 101032821
# Retrieving data for channel 101032802
# Retrieving data for channel 102032802
# Retrieving data for channel 102032821
# Retrieving data for channel 101032822
# Retrieving data for channel 102032822
# Retrieving data for channel 101032824
# Retrieving data for channel 102032824
# Retrieving data for channel 101032825
# Retrieving data for channel 102032825
# Retrieving data for channel 101032826
# Retrieving data for channel 102032826
# Retrieving data for channel 101032828
# Retrieving data for channel 102032828
# Retrieving data for channel 101032830
# Retrieving data for channel 102032830
# Retrieving data for channel 101032832
# Retrieving data for channel 102032832
# Retrieving data for channel 101032833
# Retrieving data for channel 102032833
# Retrieving data for channel 101032834
# Retrieving data for channel 102032834
# Retrieving data for channel 101032835
# Retrieving data for channel 102032835
# Retrieving data for channel 101032836
# Retrieving data for channel 102032836
# Retrieving data for channel 101032838
# Retrieving data for channel 102032838
# Retrieving data for channel 102033492
# Retrieving data for channel 101034861
# Retrieving data for channel 102034861
# Retrieving data for channel 103026960
# Retrieving data for channel 101043512
# Retrieving data for channel 102043512
# Retrieving data for channel 353399218
# Retrieving data for channel 353300368
# Retrieving data for channel 353399223
# Retrieving data for channel 104030636
# Retrieving data for channel 104030637
# Retrieving data for channel 103028454
# Retrieving data for channel 104028454
# Retrieving data for channel 100029815
# Retrieving data for channel 100034428
# Retrieving data for channel 100034429
# Retrieving data for channel 100034859
# Retrieving data for channel 100034860
# Retrieving data for channel 101043681
# Retrieving data for channel 102043681
# Retrieving data for channel 101030143
# Retrieving data for channel 102030143
# Retrieving data for channel 353243418
# Retrieving data for channel 353399217
# Retrieving data for channel 353399222
# Retrieving data for channel 103030635
# Retrieving data for channel 102031122
# Retrieving data for channel 101047688
# Retrieving data for channel 102047688
# Retrieving data for channel 101047690
# Retrieving data for channel 102047690
# Retrieving data for channel 101047692
# Retrieving data for channel 102047692
# Retrieving data for channel 101047693
# Retrieving data for channel 102047693
# Retrieving data for channel 101047694
# Retrieving data for channel 102047694
# Retrieving data for channel 101048664
# Retrieving data for channel 102048664
# Retrieving data for channel 104026960
# Retrieving data for channel 353479510
# Retrieving data for channel 101049670
# Retrieving data for channel 102049670
# Retrieving data for channel 353479511
# Retrieving data for channel 102031124
# Retrieving data for channel 101031127
# Retrieving data for channel 353244001
# Retrieving data for channel 353244005
# Retrieving data for channel 101026725
# Retrieving data for channel 102026725
# Retrieving data for channel 102031125
# Retrieving data for channel 353479386
# Retrieving data for channel 353479387
# Retrieving data for channel 353399188
# Retrieving data for channel 103031124
# Retrieving data for channel 101041017
# Retrieving data for channel 101052943
# Retrieving data for channel 102052943
# Retrieving data for channel 353399185
# Retrieving data for channel 353261920
# Retrieving data for channel 353261924
# Retrieving data for channel 101054728
# Retrieving data for channel 102054728
# Retrieving data for channel 101054729
# Retrieving data for channel 102054729
# Retrieving data for channel 101054730
# Retrieving data for channel 102054730
# Retrieving data for channel 101056211
# Retrieving data for channel 102056211
# Retrieving data for channel 101057984
# Retrieving data for channel 102057984
# Retrieving data for channel 101058579
# Retrieving data for channel 102058579
# Retrieving data for channel 103042249
# Retrieving data for channel 101030259
# Retrieving data for channel 101058580
# Retrieving data for channel 102058580
# Retrieving data for channel 101058822
# Retrieving data for channel 102058822
# Retrieving data for channel 101059636
# Retrieving data for channel 102059636
# Retrieving data for channel 101042249
# Retrieving data for channel 102031127
# Retrieving data for channel 101042252
# Retrieving data for channel 101063321
# Retrieving data for channel 102063321
# Retrieving data for channel 101063558
# Retrieving data for channel 102063558
# Retrieving data for channel 101064282
# Retrieving data for channel 102064282
# Retrieving data for channel 102045777
# Retrieving data for channel 101048989
# Retrieving data for channel 353399193
# Retrieving data for channel 102043598
# Retrieving data for channel 353303362
# Retrieving data for channel 101043680
# Retrieving data for channel 102043680
# Retrieving data for channel 103043680
# Retrieving data for channel 104043680
# Retrieving data for channel 353280420
# Retrieving data for channel 353280423
# Retrieving data for channel 353280425
# Retrieving data for channel 353280427
# Retrieving data for channel 102048989
# Retrieving data for channel 103048989
# Retrieving data for channel 104048989
# Retrieving data for channel 353399190
# Retrieving data for channel 353399191
# Retrieving data for channel 353399205
# Retrieving data for channel 353290757
# Retrieving data for channel 353399208
# Retrieving data for channel 102041017
# Retrieving data for channel 101041018
# Retrieving data for channel 102041018
# Retrieving data for channel 102042249
# Retrieving data for channel 104042249
# Retrieving data for channel 101042251
# Retrieving data for channel 102042251
# Retrieving data for channel 102042252
# Retrieving data for channel 101043598
# Retrieving data for channel 353303359
# Retrieving data for channel 105048989
# Retrieving data for channel 101031122
# Retrieving data for channel 101031128
# Retrieving data for channel 102031128
# Retrieving data for channel 353243334
# Retrieving data for channel 353399196
# Retrieving data for channel 353399199
# Retrieving data for channel 353399202
# Retrieving data for channel 104031124
# Retrieving data for channel 101031125
# Retrieving data for channel 353399187
# Retrieving data for channel 101031126
# Retrieving data for channel 102031126
# Retrieving data for channel 105062853
# Retrieving data for channel 353245798
# Retrieving data for channel 102030265
# Retrieving data for channel 101030267
# Retrieving data for channel 102030267
# Retrieving data for channel 102030269
# Retrieving data for channel 353399227
# Retrieving data for channel 101030322
# Retrieving data for channel 102030322
# Retrieving data for channel 353302086
# Retrieving data for channel 353302092
# Retrieving data for channel 104030635
# Retrieving data for channel 101031121
# Retrieving data for channel 102031121
# Retrieving data for channel 101031124
# Retrieving data for channel 101030252
# Retrieving data for channel 101030255
# Retrieving data for channel 102030255
# Retrieving data for channel 101030256
# Retrieving data for channel 102030256
# Retrieving data for channel 101030257
# Retrieving data for channel 102030257
# Retrieving data for channel 101030258
# Retrieving data for channel 102030258
# Retrieving data for channel 102030259
# Retrieving data for channel 101030260
# Retrieving data for channel 102030260
# Retrieving data for channel 101030265
# Retrieving data for channel 101030269
# Retrieving data for channel 353243423
# Retrieving data for channel 101030146
# Retrieving data for channel 353651579
# Retrieving data for channel 101030262
# Retrieving data for channel 102030262
# Retrieving data for channel 102030274
# Retrieving data for channel 101030102
# Retrieving data for channel 102030102
# Retrieving data for channel 101027497
# Retrieving data for channel 102027497
# Retrieving data for channel 353300365
# Retrieving data for channel 101013842
# Retrieving data for channel 102013842
# Retrieving data for channel 353244534
# Retrieving data for channel 353244547
# Retrieving data for channel 101017787
# Retrieving data for channel 353256147
# Retrieving data for channel 102017787
# Retrieving data for channel 102030146
# Retrieving data for channel 106048989
# Retrieving data for channel 103030636
# Retrieving data for channel 101045777
# Retrieving data for channel 102047691
# Retrieving data for channel 101049084
# Retrieving data for channel 101032516
# Retrieving data for channel 102032516
# Retrieving data for channel 102049084
# Retrieving data for channel 353399179
# Retrieving data for channel 353399180
# Retrieving data for channel 353399182
# Retrieving data for channel 353399183
# Retrieving data for channel 353399186
# Retrieving data for channel 353513450
# Retrieving data for channel 101047691
# Retrieving data for channel 101030274
# Retrieving data for channel 101050687
# Retrieving data for channel 102050687
# Retrieving data for channel 353243332
# Retrieving data for channel 103050687
# Retrieving data for channel 104050687
# Retrieving data for channel 101034819
# Retrieving data for channel 102034819
# Retrieving data for channel 353399416
# Retrieving data for channel 102030252
# Retrieving data for channel 101032819
# Retrieving data for channel 102032819
# Retrieving data for channel 105064525
# Retrieving data for channel 353245799
# Retrieving data for channel 353515329
# Retrieving data for channel 353651575
# Retrieving data for channel 101050688
# Retrieving data for channel 102050688
# Retrieving data for channel 101050689
# Retrieving data for channel 102050689
# Retrieving data for channel 353359478
# Retrieving data for channel 102050691
# Retrieving data for channel 103051225
# Retrieving data for channel 104051225
# Retrieving data for channel 103052661
# Retrieving data for channel 101053285
# Retrieving data for channel 102053285
# Retrieving data for channel 101053286
# Retrieving data for channel 102053286
# Retrieving data for channel 103053286
# Retrieving data for channel 104053286
# Retrieving data for channel 101053287
# Retrieving data for channel 102053287
# Retrieving data for channel 103053287
# Retrieving data for channel 104053287
# Retrieving data for channel 101049671
# Retrieving data for channel 102049671
# Retrieving data for channel 101049672
# Retrieving data for channel 102049672
# Retrieving data for channel 101053306
# Retrieving data for channel 102053306
# Retrieving data for channel 101033492
# Retrieving data for channel 101053564
# Retrieving data for channel 102053564
# Retrieving data for channel 101055357
# Retrieving data for channel 102055357
# Retrieving data for channel 103055357
# Retrieving data for channel 104055357
# Retrieving data for channel 101060039
# Retrieving data for channel 102060039
# Retrieving data for channel 105060039
# Retrieving data for channel 102060040
# Retrieving data for channel 103060040
# Retrieving data for channel 104060040
# Retrieving data for channel 102062853
# Retrieving data for channel 101050691
# Retrieving data for channel 104052661
# Retrieving data for channel 109062853
# Retrieving data for channel 353268133
# Retrieving data for channel 353399211
# Retrieving data for channel 353399212
# Retrieving data for channel 353399214
# Retrieving data for channel 353399215
# Retrieving data for channel 101064522
# Retrieving data for channel 102064522
# Retrieving data for channel 101063239
# Retrieving data for channel 102063239
# Retrieving data for channel 101064524
# Retrieving data for channel 353242649
# Retrieving data for channel 101064525
# Retrieving data for channel 101060040
# Retrieving data for channel 353245800
# Retrieving data for channel 353245801
# Retrieving data for channel 353246068
# Retrieving data for channel 353246069
# Retrieving data for channel 353245806
# Retrieving data for channel 353245807
# Retrieving data for channel 353245808
# Retrieving data for channel 353245809
# Retrieving data for channel 353494223
# Retrieving data for channel 353494224
# Retrieving data for channel 353246210
# Retrieving data for channel 353246211
# Retrieving data for channel 353252464
# Retrieving data for channel 353252465
# Retrieving data for channel 353252504
# Retrieving data for channel 353252506
# Retrieving data for channel 353262885
# Retrieving data for channel 353262887
# Retrieving data for channel 353262889
# Retrieving data for channel 353262891
# Retrieving data for channel 353263590
# Retrieving data for channel 353263591
# Retrieving data for channel 353263593
# Retrieving data for channel 353263595
# Retrieving data for channel 353290759
# Retrieving data for channel 353262908
# Retrieving data for channel 353262909
# Retrieving data for channel 353264046
# Retrieving data for channel 353264048
# Retrieving data for channel 353264063
# Retrieving data for channel 353264065
# Retrieving data for channel 353267473
# Retrieving data for channel 353266314
# Retrieving data for channel 353268996
# Retrieving data for channel 353268998
# Retrieving data for channel 353269000
# Retrieving data for channel 353269001
# Retrieving data for channel 353269033
# Retrieving data for channel 353264050
# Retrieving data for channel 353277144
# Retrieving data for channel 353309131
# Retrieving data for channel 353309133
# Retrieving data for channel 353264939
# Retrieving data for channel 353264943
# Retrieving data for channel 353277145
# Retrieving data for channel 353277556
# Retrieving data for channel 353277557
# Retrieving data for channel 353264965
# Retrieving data for channel 353264966
# Retrieving data for channel 353280798
# Retrieving data for channel 353280799
# Retrieving data for channel 353292128
# Retrieving data for channel 353292129
# Retrieving data for channel 353292130
# Retrieving data for channel 353292131
# Retrieving data for channel 353267772
# Retrieving data for channel 353267774
# Retrieving data for channel 353327351
# Retrieving data for channel 353327354
# Retrieving data for channel 353292377
# Retrieving data for channel 353419572
# Retrieving data for channel 353264983
# Retrieving data for channel 353264985
# Retrieving data for channel 353292471
# Retrieving data for channel 353294840
# Retrieving data for channel 353274317
# Retrieving data for channel 353274318
# Retrieving data for channel 353274320
# Retrieving data for channel 353274322
# Retrieving data for channel 353292376
# Retrieving data for channel 353293863
# Retrieving data for channel 353293865
# Retrieving data for channel 353296124
# Retrieving data for channel 353296125
# Retrieving data for channel 353297395
# Retrieving data for channel 353297397
# Retrieving data for channel 353302056
# Retrieving data for channel 353302062
# Retrieving data for channel 353302068
# Retrieving data for channel 353302074
# Retrieving data for channel 353302080
# Retrieving data for channel 353303972
# Retrieving data for channel 353303973
# Retrieving data for channel 353340937
# Retrieving data for channel 353340938
# Retrieving data for channel 353340970
# Retrieving data for channel 353340971
# Retrieving data for channel 353379130
# Retrieving data for channel 353379134
#        channel_id  count   counter_id               end_datetime  \
# 0       102017788      0  X2H14116817  2022-04-07 02:00:00+02:00
# 1       102017788      0  X2H14116817  2022-04-07 01:00:00+02:00
# 2       102017788      0  X2H14116817  2022-04-07 00:00:00+02:00
# 3       102017788      0  X2H14116817  2022-04-06 23:00:00+02:00
# 4       102017788      0  X2H14116817  2022-04-06 22:00:00+02:00
# ...           ...    ...          ...                        ...
# 262867  353303973      2  RAD000396B9  2022-04-28 07:00:00+02:00
# 262868  353303973      0  RAD000396B9  2022-04-28 06:00:00+02:00
# 262869  353303973      0  RAD000396B9  2022-04-28 05:00:00+02:00
# 262870  353303973      0  RAD000396B9  2022-04-28 04:00:00+02:00
# 262871  353303973      0  RAD000396B9  2022-04-28 03:00:00+02:00
#
#                    start_datetime
# 0       2022-04-07 01:00:00+02:00
# 1       2022-04-07 00:00:00+02:00
# 2       2022-04-06 23:00:00+02:00
# 3       2022-04-06 22:00:00+02:00
# 4       2022-04-06 21:00:00+02:00
# ...                           ...
# 262867  2022-04-28 06:00:00+02:00
# 262868  2022-04-28 05:00:00+02:00
# 262869  2022-04-28 04:00:00+02:00
# 262870  2022-04-28 03:00:00+02:00
# 262871  2022-04-28 02:00:00+02:00
#
# [262872 rows x 5 columns]

# %%
# Convert dataframe to csv
all_data.to_csv('./CSVs/counting_data_april_2022.csv', sep=';', index=False)
